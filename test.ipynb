# %%
import pandas as pd

data = pd.read_csv('./aceh_production_data_daily_ed.csv')
data['WELL_BORE_CODE'].unique().tolist()
# Out:
# ['Well-C1', 'Well-E1', 'Well-N1', 'Well-N2', 'Well-S1', 'Well-W1', 'Well-W2']

# %%
def data_multiselect(values):
    return [{"label": value, "value": value} for value in values]

# %%
data_multiselect(data['WELL_BORE_CODE'].unique().tolist())
# Out:
# [{'label': 'Well-C1', 'value': 'Well-C1'},
#  {'label': 'Well-E1', 'value': 'Well-E1'},
#  {'label': 'Well-N1', 'value': 'Well-N1'},
#  {'label': 'Well-N2', 'value': 'Well-N2'},
#  {'label': 'Well-S1', 'value': 'Well-S1'},
#  {'label': 'Well-W1', 'value': 'Well-W1'},
#  {'label': 'Well-W2', 'value': 'Well-W2'}]

# %%
data['WATER_CUT_DAILY'] = (data['BORE_WAT_VOL'] / (data['BORE_OIL_VOL'] + data['BORE_GAS_VOL'] + data['BORE_WAT_VOL'])) * 100
data['GAS_OIL_RATIO'] = data['BORE_GAS_VOL'] / data['BORE_OIL_VOL']

# %%
pivot = data.pivot_table(values= ['WATER_CUT_DAILY','BORE_OIL_VOL'],
                 index=[data['DATEPRD']],
                 aggfunc='mean',
                 dropna=True
                 )

# %%
pivot
# Out:
#             BORE_OIL_VOL  WATER_CUT_DAILY
# DATEPRD
# 2008-02-12       142.325         0.973272
# 2008-02-13       934.850         0.002483
# 2008-02-14      1562.045         0.000226
# 2008-02-15      1304.140         0.000251
# 2008-02-16      1525.900         0.001160
# ...                  ...              ...
# 2016-09-13       108.762         3.314492
# 2016-09-14       108.376         3.162934
# 2016-09-15       106.974         2.980009
# 2016-09-16       106.054         2.952975
# 2016-09-17        36.008         2.697111
#
# [3056 rows x 2 columns]

# %%
filtered = []
for index, row in pivot.iterrows():
    filtered.append({'DATEPRD': index, **row.to_dict()})

# %%
filtered.to_dict('records')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 filtered.to_dict('records')
#
# AttributeError: 'list' object has no attribute 'to_dict'

# %%
pivot.to_dict('records')
# Out:
# [{'BORE_OIL_VOL': 142.325, 'WATER_CUT_DAILY': 0.9732716219314616},
#  {'BORE_OIL_VOL': 934.85, 'WATER_CUT_DAILY': 0.0024832563912767836},
#  {'BORE_OIL_VOL': 1562.045, 'WATER_CUT_DAILY': 0.00022608554340235315},
#  {'BORE_OIL_VOL': 1304.14, 'WATER_CUT_DAILY': 0.0002512719541746271},
#  {'BORE_OIL_VOL': 1525.9, 'WATER_CUT_DAILY': 0.0011600578833299183},
#  {'BORE_OIL_VOL': 1491.315, 'WATER_CUT_DAILY': 0.0004345298767241089},
#  {'BORE_OIL_VOL': 1490.26, 'WATER_CUT_DAILY': 0.0015546353564385418},
#  {'BORE_OIL_VOL': 1523.095, 'WATER_CUT_DAILY': 0.0001688779186615467},
#  {'BORE_OIL_VOL': 1528.59, 'WATER_CUT_DAILY': 0.00010312967397414392},
#  {'BORE_OIL_VOL': 1515.165, 'WATER_CUT_DAILY': 0.00010542593553920938},
#  {'BORE_OIL_VOL': 1453.78, 'WATER_CUT_DAILY': 0.00010980345182123999},
#  {'BORE_OIL_VOL': 925.86, 'WATER_CUT_DAILY': 0.00011026660890796676},
#  {'BORE_OIL_VOL': 1563.35, 'WATER_CUT_DAILY': 0.00010539648622018309},
# ...

# %%
columns=[{'name': i, 'id': i} for i in data.columns]

# %%
columns
# Out:
# [{'name': 'DATEPRD', 'id': 'DATEPRD'},
#  {'name': 'WELL_BORE_CODE', 'id': 'WELL_BORE_CODE'},
#  {'name': 'ON_STREAM_HRS', 'id': 'ON_STREAM_HRS'},
#  {'name': 'AVG_DOWNHOLE_PRESSURE', 'id': 'AVG_DOWNHOLE_PRESSURE'},
#  {'name': 'AVG_DP_TUBING', 'id': 'AVG_DP_TUBING'},
#  {'name': 'AVG_WHP_P', 'id': 'AVG_WHP_P'},
#  {'name': 'AVG_WHT_P', 'id': 'AVG_WHT_P'},
#  {'name': 'DP_CHOKE_SIZE', 'id': 'DP_CHOKE_SIZE'},
#  {'name': 'BORE_OIL_VOL', 'id': 'BORE_OIL_VOL'},
#  {'name': 'BORE_GAS_VOL', 'id': 'BORE_GAS_VOL'},
#  {'name': 'BORE_WAT_VOL', 'id': 'BORE_WAT_VOL'},
#  {'name': 'BORE_WI_VOL', 'id': 'BORE_WI_VOL'},
#  {'name': 'FLOW_KIND', 'id': 'FLOW_KIND'}]

# %%
test = [['Well-C1']]

# %%
data
# Out:
#           DATEPRD WELL_BORE_CODE  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 0      2008-02-12        Well-C1            0.0                    0.0
# 1      2008-02-13        Well-C1            0.0                    0.0
# 2      2008-02-14        Well-C1            0.0                    0.0
# 3      2008-02-15        Well-C1            0.0                    0.0
# 4      2008-02-16        Well-C1            0.0                    0.0
# ...           ...            ...            ...                    ...
# 15629  2016-10-05        Well-W2            NaN                    NaN
# 15630  2016-10-06        Well-W2            NaN                    NaN
# 15631  2016-10-07        Well-W2            NaN                    NaN
# 15632  2016-11-01        Well-W2            NaN                    NaN
# 15633  2016-12-01        Well-W2            NaN                    NaN
#
#        AVG_DP_TUBING  AVG_WHP_P  AVG_WHT_P  DP_CHOKE_SIZE  BORE_OIL_VOL  \
# ...

# %%
data[data['WELL_BORE_CODE'].isin(['Well-C1','Well-E1'])]
# Out:
#          DATEPRD WELL_BORE_CODE  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 0     2008-02-12        Well-C1            0.0                0.00000
# 1     2008-02-13        Well-C1            0.0                0.00000
# 2     2008-02-14        Well-C1            0.0                0.00000
# 3     2008-02-15        Well-C1            0.0                0.00000
# 4     2008-02-16        Well-C1            0.0                0.00000
# ...          ...            ...            ...                    ...
# 3797  2016-04-17        Well-E1            0.0              270.26849
# 3798  2016-04-18        Well-E1            0.0              276.86895
# 3799  2016-04-19        Well-E1            0.0              282.10538
# 3800  2016-04-20        Well-E1            0.0              285.09577
# 3801  2016-04-21        Well-E1            0.0                0.00000
#
#       AVG_DP_TUBING  AVG_WHP_P  AVG_WHT_P  DP_CHOKE_SIZE  BORE_OIL_VOL  \
# ...
